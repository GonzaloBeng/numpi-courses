# %% [markdown]
# <font color=Green>
#
# # **4.5 Presentacion de Analisis**
#
# </font>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_crudo = pd.read_csv(r'C:\Users\Gonza\Documents\codigo\numpi-courses\intro_data_analysis/dow_jones_index.data')
df_crudo
# Out:
#      quarter stock       date    open    high     low   close     volume  \
# 0          1    AA   1/7/2011  $15.82  $16.72  $15.78  $16.42  239655616
# 1          1    AA  1/14/2011  $16.71  $16.71  $15.64  $15.97  242963398
# 2          1    AA  1/21/2011  $16.19  $16.38  $15.60  $15.79  138428495
# 3          1    AA  1/28/2011  $15.87  $16.63  $15.82  $16.13  151379173
# 4          1    AA   2/4/2011  $16.18  $17.39  $16.18  $17.14  154387761
# ..       ...   ...        ...     ...     ...     ...     ...        ...
# 745        2   XOM  5/27/2011  $80.22  $82.63  $80.07  $82.63   68230855
# 746        2   XOM   6/3/2011  $83.28  $83.75  $80.18  $81.18   78616295
# 747        2   XOM  6/10/2011  $80.93  $81.87  $79.72  $79.78   92380844
# 748        2   XOM  6/17/2011  $80.00  $80.82  $78.33  $79.02  100521400
# 749        2   XOM  6/24/2011  $78.65  $81.12  $76.78  $76.78  118679791
#
#      percent_change_price  percent_change_volume_over_last_wk  \
# ...

# %% [markdown]
# #### El parametro converters de la funcion `pd.read_csv()` nos permite aplicar una operacion en las columnas.

# %%
columnas = ['accion', 'fecha', 'precio']

df = pd.read_csv(r'C:\Users\Gonza\Documents\codigo\numpi-courses\intro_data_analysis/dow_jones_index.data',
                    usecols=[1,2,6],
                    header=0,
                    names=columnas,
                    parse_dates=['fecha'],
                    converters={'precio': 
                                lambda x:
                                float(x.replace('$',''))
                                }
                )
df
# Out:
#     accion      fecha  precio
# 0       AA 2011-01-07   16.42
# 1       AA 2011-01-14   15.97
# 2       AA 2011-01-21   15.79
# 3       AA 2011-01-28   16.13
# 4       AA 2011-02-04   17.14
# ..     ...        ...     ...
# 745    XOM 2011-05-27   82.63
# 746    XOM 2011-06-03   81.18
# 747    XOM 2011-06-10   79.78
# 748    XOM 2011-06-17   79.02
# 749    XOM 2011-06-24   76.78
#
# [750 rows x 3 columns]

# %% [markdown]
# #### Primero entender los datos contenidos en el csv.

# %% [markdown]
# ## <font color=#003d5c> _Que periodo en el tiempo representan los datos?_ </font>

# %%
df.fecha.dt.year.value_counts()
# Out:
# 2011    750
# Name: fecha, dtype: int64

# %% [markdown]
# + Las datos pertenecen al año 2011.

# %%
df.fecha.dt.month.value_counts() #Usa a los meses con numeros (poco practico)
# Out:
# 4    150
# 1    120
# 2    120
# 3    120
# 5    120
# 6    120
# Name: fecha, dtype: int64

# %% [markdown]
# + Los datos se distribuyen desde Enero a Junio del 2011: _Primer semestre del año._
# + En el mes de Abril hay 30 registros más que en el resto de los meses: _Por qué?._

# %%
df.fecha.dt.month_name().value_counts() #Correccion
# Out:
# April       150
# January     120
# February    120
# March       120
# May         120
# June        120
# Name: fecha, dtype: int64

# %%
df['mes'] = df.fecha.dt.month_name()
filtro1 = df['mes'] =='April'
filtro2 = df['mes'] =='May'

# %%
df[filtro1].groupby('accion')['mes'].value_counts()
# Out:
# accion  mes
# AA      April    5
# AXP     April    5
# BA      April    5
# BAC     April    5
# CAT     April    5
# CSCO    April    5
# CVX     April    5
# DD      April    5
# DIS     April    5
# GE      April    5
# HD      April    5
# HPQ     April    5
# IBM     April    5
# INTC    April    5
# JNJ     April    5
# JPM     April    5
# KO      April    5
# KRFT    April    5
# MCD     April    5
# MMM     April    5
# MRK     April    5
# MSFT    April    5
# PFE     April    5
# PG      April    5
# T       April    5
# TRV     April    5
# UTX     April    5
# VZ      April    5
# WMT     April    5
# XOM     April    5
# Name: mes, dtype: int64

# %%
df[filtro2].groupby('accion')['mes'].value_counts()
# Out:
# accion  mes
# AA      May    4
# AXP     May    4
# BA      May    4
# BAC     May    4
# CAT     May    4
# CSCO    May    4
# CVX     May    4
# DD      May    4
# DIS     May    4
# GE      May    4
# HD      May    4
# HPQ     May    4
# IBM     May    4
# INTC    May    4
# JNJ     May    4
# JPM     May    4
# KO      May    4
# KRFT    May    4
# MCD     May    4
# MMM     May    4
# MRK     May    4
# MSFT    May    4
# PFE     May    4
# PG      May    4
# T       May    4
# TRV     May    4
# UTX     May    4
# VZ      May    4
# WMT     May    4
# XOM     May    4
# Name: mes, dtype: int64

# %% [markdown]
# + En Abril las acciones cotizaron 5 veces porque el mes tuvo 5 semanas.

# %% [markdown]
# ## <font color=#003d5c> _Cuáles acciones en promedio tuvieron la mayor y la menor cotización?_ </font>

# %%
df.groupby('accion').agg({'precio': [np.mean, np.std]})
# Out:
#           precio
#             mean       std
# accion
# AA       16.5044  0.772922
# AXP      46.7124  2.396248
# BA       73.4480  3.087631
# BAC      13.0516  1.417382
# CAT     103.1520  6.218651
# CSCO     17.8992  1.984095
# CVX     101.1756  5.267066
# DD       52.8736  2.367048
# DIS      41.2496  1.882473
# GE       19.7840  0.912022
# HD       36.5600  1.270213
# HPQ      41.5364  4.263754
# IBM     163.1016  5.730211
# INTC     21.4352  1.072272
# JNJ      62.6236  2.846177
# JPM      44.4996  2.095094
# KO       65.3264  1.970774
# KRFT     32.5576  1.570584
# MCD      77.2704  3.004153
# MMM      91.6980  2.692709
# MRK      34.3604  1.666357
# MSFT     25.9208  1.416407
# PFE      19.8216  0.915085
# PG       64.0020  1.828795
# T        29.6268  1.369257
# TRV      59.1600  2.649218
# UTX      84.0332  2.985547
# VZ       36.4696  0.932820
# WMT      53.9128  1.555639
# XOM      82.1116  3.137743

# %%
df.groupby('accion').agg({'precio': [np.mean, np.std]}).sort_values([('precio','mean')], ascending=False)
# Out:
#           precio
#             mean       std
# accion
# IBM     163.1016  5.730211
# CAT     103.1520  6.218651
# CVX     101.1756  5.267066
# MMM      91.6980  2.692709
# UTX      84.0332  2.985547
# XOM      82.1116  3.137743
# MCD      77.2704  3.004153
# BA       73.4480  3.087631
# KO       65.3264  1.970774
# PG       64.0020  1.828795
# JNJ      62.6236  2.846177
# TRV      59.1600  2.649218
# WMT      53.9128  1.555639
# DD       52.8736  2.367048
# AXP      46.7124  2.396248
# JPM      44.4996  2.095094
# HPQ      41.5364  4.263754
# DIS      41.2496  1.882473
# HD       36.5600  1.270213
# VZ       36.4696  0.932820
# MRK      34.3604  1.666357
# KRFT     32.5576  1.570584
# T        29.6268  1.369257
# MSFT     25.9208  1.416407
# INTC     21.4352  1.072272
# PFE      19.8216  0.915085
# GE       19.7840  0.912022
# CSCO     17.8992  1.984095
# AA       16.5044  0.772922
# BAC      13.0516  1.417382

# %% [markdown]
# + En promedio IBM tuvo el mayor precio: 163,10 USD
# + En promedio BAC tuvo el menor precio: 13,05 USD

# %% [markdown]
# ## <font color=#003d5c> _Cuáles acciones en promedio tuvieron la mayor y la menor variacion de precio?_ </font>

# %%
df.groupby('accion').agg({'precio': [np.mean, np.std]}).sort_values([('precio', 'std')], ascending=False)
# Out:
#           precio
#             mean       std
# accion
# CAT     103.1520  6.218651
# IBM     163.1016  5.730211
# CVX     101.1756  5.267066
# HPQ      41.5364  4.263754
# XOM      82.1116  3.137743
# BA       73.4480  3.087631
# MCD      77.2704  3.004153
# UTX      84.0332  2.985547
# JNJ      62.6236  2.846177
# MMM      91.6980  2.692709
# TRV      59.1600  2.649218
# AXP      46.7124  2.396248
# DD       52.8736  2.367048
# JPM      44.4996  2.095094
# CSCO     17.8992  1.984095
# KO       65.3264  1.970774
# DIS      41.2496  1.882473
# PG       64.0020  1.828795
# MRK      34.3604  1.666357
# KRFT     32.5576  1.570584
# WMT      53.9128  1.555639
# BAC      13.0516  1.417382
# MSFT     25.9208  1.416407
# T        29.6268  1.369257
# HD       36.5600  1.270213
# INTC     21.4352  1.072272
# VZ       36.4696  0.932820
# PFE      19.8216  0.915085
# GE       19.7840  0.912022
# AA       16.5044  0.772922

# %% [markdown]
# + CAT es la acción más volátil, con una desviación tipica de 6,22 USD
# + AA es la acción más consistente, con una desviación típica de 0,77 USD

# %% [markdown]
# ### Ya que conocemos la acción más volátil, podemos preguntarnos si el precio de esta acción tiene correlación con el precio de otras acciones.
#
# ### Deseamos estudiar una o varias acciones particulares pero el conjunto de datos no presenta un formato conveniente para esto.
#
# ### La función `df.pivot_table()` nos genera un nuevo `DataFrame` reorganizado con la forma que deseemos.

# %%
df_nuevo = df.pivot_table(index='fecha',
                            columns='accion',
                            values='precio')
df_nuevo
# Out:
# accion         AA    AXP     BA    BAC     CAT   CSCO     CVX     DD    DIS  \
# fecha
# 2011-01-07  16.42  44.36  69.38  14.25   93.73  20.97   91.19  49.76  39.45
# 2011-01-14  15.97  46.25  70.07  15.25   94.01  21.21   92.83  49.80  39.29
# 2011-01-21  15.79  46.00  71.68  14.25   92.75  20.72   93.78  48.35  39.74
# 2011-01-28  16.13  43.86  69.23  13.60   95.68  20.93   93.37  50.29  38.85
# 2011-02-04  17.14  43.82  71.38  14.29   99.59  22.05   97.11  52.53  40.71
# 2011-02-11  17.37  46.75  72.14  14.77  103.54  18.70   96.45  54.58  43.41
# 2011-02-18  17.28  45.53  73.04  14.75  105.86  18.85   98.72  55.98  43.56
# 2011-02-25  16.68  43.53  72.30  14.20  102.00  18.64  102.10  54.07  42.95
# 2011-03-04  16.58  43.72  71.80  14.12  103.04  18.40  103.75  53.87  43.55
# 2011-03-11  16.03  44.28  71.64  14.38  100.02  17.95   99.93  52.90  42.93
# 2011-03-18  16.11  44.17  69.10  14.04  105.06  17.14  102.80  52.99  41.23
# ...

# %% [markdown]
# ### Ahora podemos centrarnos en estudiar el comportamiento en el tiempo de cada acción.

# %%
fig, (pan1, pan2) = plt.subplots(2,1, sharex=True, constrained_layout=True)

pan1.plot(df_nuevo.index, df_nuevo.CAT,
            color = 'Blue',
            marker = 'o',
            linestyle = 'solid',
            label = 'CAT')


pan2.plot(df_nuevo.index, df_nuevo.AA,
            color = 'Orange',
            marker = 'v',
            linestyle = 'solid',
            label = 'AA')


for pan in fig.get_axes():
    pan.set(xlabel='Fecha',
            ylabel='Dolares Estadounidenses',
            title='Precio de la accion (al cierre).')

pan1.legend()
pan2.legend()

# %% [markdown]
# + Los precios de ambas acciones presentan un comportamiento alcista hasta Abril -con un ligero declive en las primeras semanas de Marzo-, a partir de ahí el precio baja hasta la última semana de Junio.

# %% [markdown]
# ## <font color=#003d5c> _Existe alguna correlación entre los precios de CAT y el resto de las acciones?_ </font>

# %%
df_nuevo.corr() #Llamar una matriz de correlaciones
# Out:
# accion        AA       AXP        BA       BAC       CAT      CSCO       CVX  \
# accion
# AA      1.000000 -0.132094  0.291520  0.432240  0.695727  0.277191  0.470529
# AXP    -0.132094  1.000000  0.792575 -0.746595  0.255515 -0.593743  0.236456
# BA      0.291520  0.792575  1.000000 -0.536545  0.627205 -0.465162  0.568946
# BAC     0.432240 -0.746595 -0.536545  1.000000 -0.131058  0.813696 -0.295246
# CAT     0.695727  0.255515  0.627205 -0.131058  1.000000 -0.375140  0.889416
# CSCO    0.277191 -0.593743 -0.465162  0.813696 -0.375140  1.000000 -0.548609
# CVX     0.470529  0.236456  0.568946 -0.295246  0.889416 -0.548609  1.000000
# DD      0.762246  0.004094  0.417249  0.129762  0.902856 -0.175626  0.753270
# DIS     0.772470 -0.129064  0.350917  0.421660  0.712870  0.067161  0.555978
# GE      0.740139 -0.315425  0.139263  0.568918  0.463054  0.362102  0.266078
# HD      0.744726 -0.201676  0.208978  0.461699  0.617550  0.227759  0.455472
# ...

# %%
df_nuevo.corr().loc['CAT']
# Out:
# accion
# AA      0.695727
# AXP     0.255515
# BA      0.627205
# BAC    -0.131058
# CAT     1.000000
# CSCO   -0.375140
# CVX     0.889416
# DD      0.902856
# DIS     0.712870
# GE      0.463054
# HD      0.617550
# HPQ    -0.153858
# IBM     0.665304
# INTC    0.141202
# JNJ    -0.072006
# JPM     0.403562
# KO      0.699167
# KRFT    0.185959
# MCD     0.106767
# MMM     0.806474
# MRK    -0.030892
# MSFT   -0.325324
# PFE     0.666647
# PG     -0.226021
# T       0.482533
# TRV     0.778439
# UTX     0.734655
# VZ      0.890315
# WMT    -0.170677
# XOM     0.803195
# Name: CAT, dtype: float64

# %%
df_nuevo.corr().loc['CAT'][df_nuevo.corr().loc['CAT'] > 0.8]
# Out:
# accion
# CAT    1.000000
# CVX    0.889416
# DD     0.902856
# MMM    0.806474
# VZ     0.890315
# XOM    0.803195
# Name: CAT, dtype: float64

# %%
corr_pos = df_nuevo.corr().loc['CAT'][df_nuevo.corr().loc['CAT'] > 0.8].sort_values(ascending=False)
corr_pos
# Out:
# accion
# CAT    1.000000
# DD     0.902856
# VZ     0.890315
# CVX    0.889416
# MMM    0.806474
# XOM    0.803195
# Name: CAT, dtype: float64

# %% [markdown]
# + Las acciones DD, VZ, CVX, MMM, XOM presentan una fuerte correlación positiva con CAT.

# %%
valores = corr_pos[1:5]

plt.bar(valores.index, valores.values, color='forestgreen')

plt.plot()

plt.xlabel("Acciones")

plt.ylabel("Coeficiente de correlación.")

plt.title('Correlación entre CAT y el resto.')

plt.show()

# %%
corr_neg = df_nuevo.corr().loc['CAT'][df_nuevo.corr().loc['CAT'] < 0].sort_values(ascending=True)
corr_neg
# Out:
# accion
# CSCO   -0.375140
# MSFT   -0.325324
# PG     -0.226021
# WMT    -0.170677
# HPQ    -0.153858
# BAC    -0.131058
# JNJ    -0.072006
# MRK    -0.030892
# Name: CAT, dtype: float64

# %%
valores = corr_neg[1:5]

plt.bar(valores.index, valores.values, color='brown')

plt.plot()

plt.xlabel("Acciones")

plt.ylabel("Coeficiente de correlación.")

plt.title('Correlación entre CAT y el resto.')

plt.show()

# %% [markdown]
# + Ninguna acción presenta una correlación negativa significante con CAT.
